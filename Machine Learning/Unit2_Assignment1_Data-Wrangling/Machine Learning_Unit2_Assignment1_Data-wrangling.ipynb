# %% [markdown]
# **Scikit Learn**

# %%
import sklearn    # machine learning
import numpy as np  # computation
import pandas as pd # data management

# %%
# 1. load the data set
dataset = pd.read_csv("https://raw.githubusercontent.com/kit-sereyvath/Machine-Learning--Data-Wrangling/main/tech_fundings.csv")
dataset.head(10)
# Out:
#        Company                       Website          Region  \
# 0     Internxt         https://internxt.com/           Spain
# 1     Dockflow          https://dockflow.com         Belgium
# 2    api.video             https://api.video          France
# 3      Buck.ai              https://buck.ai/   United States
# 4    Prodsight      https://www.prodsight.ai  United Kingdom
# 5     Harvestr           http://harvestr.io/          France
# 6      Seatrec           http://seatrec.com/   United States
# 7    BeeCanvas      https://beecanvas.com/en   United States
# 8  SmartKarrot  https://www.smartkarrot.com/   United States
# 9      Prisync           https://prisync.com          Turkey
#
#                   Vertical  Funding Amount (USD) Funding Stage Funding Date
# 0               Blockchain              278940.0          Seed       20-Jan
# 1                Logistics              292244.0          Seed       20-Jan
# 2           Developer APIs              300000.0          Seed       20-Jan
# 3  Artificial Intelligence              300000.0          Seed       20-Jan
# 4  Artificial Intelligence              529013.0          Seed       20-Jan
# 5             B2B Software              650000.0         Angel       20-Jan
# 6        Marine Technology              970000.0          Seed       20-Jan
# 7             B2B Software             1000000.0          Seed       20-Jan
# 8             B2B Software             1000000.0         Angel       20-Jan
# 9             B2B Software             1100000.0          Seed       20-Jan

# %% [markdown]
# ############################################

# %%
# Dimension: row, column
dataset.shape
# Out:
# (3575, 7)

# %%
dataset.describe()
# Out:
#        Funding Amount (USD)
# count          3.566000e+03
# mean           5.756014e+07
# std            2.981976e+08
# min            4.000000e+04
# 25%            5.000000e+06
# 50%            1.549630e+07
# 75%            5.000000e+07
# max            1.660000e+10

# %% [markdown]
# ################################################################################

# %%
# Check the variable (numerical / categorical)
numerical_variable = dataset.columns[dataset.dtypes != 'object']  # looking for numerical data
dataset[numerical_variable].head(5)
# Out:
#    Funding Amount (USD)
# 0              278940.0
# 1              292244.0
# 2              300000.0
# 3              300000.0
# 4              529013.0

# %%
# Check the variable (numerical / categorical)
categorical_variable = dataset.columns[dataset.dtypes == 'object']  # looking for categorical data
dataset[categorical_variable].head(5)
# Out:
#      Company                   Website          Region  \
# 0   Internxt     https://internxt.com/           Spain
# 1   Dockflow      https://dockflow.com         Belgium
# 2  api.video         https://api.video          France
# 3    Buck.ai          https://buck.ai/   United States
# 4  Prodsight  https://www.prodsight.ai  United Kingdom
#
#                   Vertical Funding Stage Funding Date
# 0               Blockchain          Seed       20-Jan
# 1                Logistics          Seed       20-Jan
# 2           Developer APIs          Seed       20-Jan
# 3  Artificial Intelligence          Seed       20-Jan
# 4  Artificial Intelligence          Seed       20-Jan

# %% [markdown]
# ################################################################################

# %%
# Missing value
dataset.isnull().head(5)    # in province column is true because it contain NaN which means no data

# False = no missing value
# True = have missing value
# Out:
#    Company  Website  Region  Vertical  Funding Amount (USD)  Funding Stage  \
# 0    False    False   False     False                 False          False
# 1    False    False   False     False                 False          False
# 2    False    False   False     False                 False          False
# 3    False    False   False     False                 False          False
# 4    False    False   False     False                 False          False
#
#    Funding Date
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False

# %% [markdown]
# ################################################################################

# %%
# Find the percentage of missing value in numerical variable
dataset[numerical_variable].isnull().sum() / len(dataset)
# Out:
# Funding Amount (USD)    0.002517
# dtype: float64

# %%
# Find the percentage of missing value in categorical variable
dataset[categorical_variable].isnull().sum() / len(dataset)
# Out:
# Company          0.000000
# Website          0.000000
# Region           0.003357
# Vertical         0.000000
# Funding Stage    0.000000
# Funding Date     0.000000
# dtype: float64

# %% [markdown]
# ################################################################################

# %%
# Replace missing value
dataset[categorical_variable].fillna("Cambodia")
# Out:
#              Company                      Website          Region  \
# 0           Internxt        https://internxt.com/           Spain
# 1           Dockflow         https://dockflow.com         Belgium
# 2          api.video            https://api.video          France
# 3            Buck.ai             https://buck.ai/   United States
# 4          Prodsight     https://www.prodsight.ai  United Kingdom
# ...              ...                          ...             ...
# 3570         Headout      https://www.headout.com   United States
# 3571            OLIO          https://olioex.com/  United Kingdom
# 3572  Trees for Life  https://treesforlife.org.uk  United Kingdom
# 3573     Britishvolt     https://britishvolt.com/  United Kingdom
# 3574         Greenly   https://www.greenly.earth/          France
#
#                      Vertical Funding Stage Funding Date
# 0                  Blockchain          Seed       20-Jan
# 1                   Logistics          Seed       20-Jan
# 2              Developer APIs          Seed       20-Jan
# 3     Artificial Intelligence          Seed       20-Jan
# 4     Artificial Intelligence          Seed       20-Jan
# ...                       ...           ...          ...
# 3570                   Travel      Series B       21-Sep
# 3571                 Wellness      Series B       21-Sep
# 3572                 Wellness  Crowdfunding       21-Sep
# 3573                 Wellness      Series B       21-Sep
# 3574                 Wellness          Seed       21-Sep
#
# [3575 rows x 6 columns]

# %%
# Replace missing value
dataset[numerical_variable].fillna(111)
# Out:
#       Funding Amount (USD)
# 0                 278940.0
# 1                 292244.0
# 2                 300000.0
# 3                 300000.0
# 4                 529013.0
# ...                    ...
# 3570            12000000.0
# 3571            43000000.0
# 3572             2737468.0
# 3573            70000000.0
# 3574             2953675.0
#
# [3575 rows x 1 columns]

# %%
# Replace value
dataset['Region'].replace("Cambodia", "Unknown")
# Out:
# 0                Spain
# 1              Belgium
# 2               France
# 3        United States
# 4       United Kingdom
#              ...
# 3570     United States
# 3571    United Kingdom
# 3572    United Kingdom
# 3573    United Kingdom
# 3574            France
# Name: Region, Length: 3575, dtype: object

# %% [markdown]
# ################################################################################

# %%
# Insert new row into the dataset
row_insert = pd.Series(['Tour Arista', 'https://tourarista.com/', 'Cambodia', 'Tourism', 100000, 'Seed', '12-Dec'], index = ['Company', 'Website', 'Region', 'Vertical', 'Funding Amount (USD)', 'Funding Stage', 'Funding Date'])
dataset.append(row_insert, ignore_index=True)
# Out:
#              Company                      Website          Region  \
# 0           Internxt        https://internxt.com/           Spain
# 1           Dockflow         https://dockflow.com         Belgium
# 2          api.video            https://api.video          France
# 3            Buck.ai             https://buck.ai/   United States
# 4          Prodsight     https://www.prodsight.ai  United Kingdom
# ...              ...                          ...             ...
# 3571            OLIO          https://olioex.com/  United Kingdom
# 3572  Trees for Life  https://treesforlife.org.uk  United Kingdom
# 3573     Britishvolt     https://britishvolt.com/  United Kingdom
# 3574         Greenly   https://www.greenly.earth/          France
# 3575     Tour Arista      https://tourarista.com/        Cambodia
#
#                      Vertical  Funding Amount (USD) Funding Stage Funding Date
# 0                  Blockchain              278940.0          Seed       20-Jan
# 1                   Logistics              292244.0          Seed       20-Jan
# 2              Developer APIs              300000.0          Seed       20-Jan
# 3     Artificial Intelligence              300000.0          Seed       20-Jan
# 4     Artificial Intelligence              529013.0          Seed       20-Jan
# ...                       ...                   ...           ...          ...
# 3571                 Wellness            43000000.0      Series B       21-Sep
# 3572                 Wellness             2737468.0  Crowdfunding       21-Sep
# 3573                 Wellness            70000000.0      Series B       21-Sep
# 3574                 Wellness             2953675.0          Seed       21-Sep
# 3575                  Tourism              100000.0          Seed       12-Dec
#
# [3576 rows x 7 columns]

# %% [markdown]
# ################################################################################

# %%
# Call specific row in dataset
dataset.iloc[111]
# dataset.iloc[3:7]
# Out:
# Company                                 SpotOn
# Website                 https://www.spoton.com
# Region                           United States
# Vertical                               FinTech
# Funding Amount (USD)                50000000.0
# Funding Stage                         Series B
# Funding Date                            20-Mar
# Name: 111, dtype: object

# %%
# Call specific row in dataset based on value
dataset = dataset.set_index(dataset['Funding Date'])   # tell dataset which column we going to use in searching for matching value
dataset.loc['21-Sep']
# Out:
#                            Company                        Website  \
# Funding Date
# 21-Sep                       AON3D              https://aon3d.com
# 21-Sep                   FLYR Labs           https://flyrlabs.com
# 21-Sep        Avia Solutions Group             https://aviasg.com
# 21-Sep           Urban Aeronautics     https://www.urbanaero.com/
# 21-Sep             Near Space Labs  https://www.nearspacelabs.com
# ...                            ...                            ...
# 21-Sep                     Headout        https://www.headout.com
# 21-Sep                        OLIO            https://olioex.com/
# 21-Sep              Trees for Life    https://treesforlife.org.uk
# 21-Sep                 Britishvolt       https://britishvolt.com/
# 21-Sep                     Greenly     https://www.greenly.earth/
#
#                       Region   Vertical  Funding Amount (USD)   Funding Stage  \
# Funding Date
# 21-Sep                Canada         3D            11500000.0        Series A
# 21-Sep         United States  Aerospace           150000000.0        Series C
# 21-Sep                Cyprus  Aerospace           351360000.0  Private Equity
# 21-Sep                Israel  Aerospace            10000000.0        Series A
# 21-Sep         United States  Aerospace            13000000.0        Series A
# ...                      ...        ...                   ...             ...
# 21-Sep         United States     Travel            12000000.0        Series B
# 21-Sep        United Kingdom   Wellness            43000000.0        Series B
# 21-Sep        United Kingdom   Wellness             2737468.0    Crowdfunding
# 21-Sep        United Kingdom   Wellness            70000000.0        Series B
# 21-Sep                France   Wellness             2953675.0            Seed
#
#              Funding Date
# Funding Date
# 21-Sep             21-Sep
# 21-Sep             21-Sep
# 21-Sep             21-Sep
# 21-Sep             21-Sep
# 21-Sep             21-Sep
# ...                   ...
# 21-Sep             21-Sep
# 21-Sep             21-Sep
# 21-Sep             21-Sep
# 21-Sep             21-Sep
# 21-Sep             21-Sep
#
# [314 rows x 7 columns]

# %% [markdown]
# ################################################################################

# %%
# Rename column in dataset
dataset.rename(columns={'Funding Amount (USD)': 'FA (USD)'})
# Out:
#              Company                      Website          Region  \
# 0           Internxt        https://internxt.com/           Spain
# 1           Dockflow         https://dockflow.com         Belgium
# 2          api.video            https://api.video          France
# 3            Buck.ai             https://buck.ai/   United States
# 4          Prodsight     https://www.prodsight.ai  United Kingdom
# ...              ...                          ...             ...
# 3570         Headout      https://www.headout.com   United States
# 3571            OLIO          https://olioex.com/  United Kingdom
# 3572  Trees for Life  https://treesforlife.org.uk  United Kingdom
# 3573     Britishvolt     https://britishvolt.com/  United Kingdom
# 3574         Greenly   https://www.greenly.earth/          France
#
#                      Vertical    FA (USD) Funding Stage Funding Date
# 0                  Blockchain    278940.0          Seed       20-Jan
# 1                   Logistics    292244.0          Seed       20-Jan
# 2              Developer APIs    300000.0          Seed       20-Jan
# 3     Artificial Intelligence    300000.0          Seed       20-Jan
# 4     Artificial Intelligence    529013.0          Seed       20-Jan
# ...                       ...         ...           ...          ...
# 3570                   Travel  12000000.0      Series B       21-Sep
# 3571                 Wellness  43000000.0      Series B       21-Sep
# 3572                 Wellness   2737468.0  Crowdfunding       21-Sep
# 3573                 Wellness  70000000.0      Series B       21-Sep
# 3574                 Wellness   2953675.0          Seed       21-Sep
#
# [3575 rows x 7 columns]

# %% [markdown]
# ################################################################################

# %%
# Delete column from the dataset
dataset.drop('Website', axis=1)
# or : dataset.drop(dataset.column[1], axis=1)    because "Province/State" is in index 1 of the list of columns
# Out:
#              Company          Region                 Vertical  \
# 0           Internxt           Spain               Blockchain
# 1           Dockflow         Belgium                Logistics
# 2          api.video          France           Developer APIs
# 3            Buck.ai   United States  Artificial Intelligence
# 4          Prodsight  United Kingdom  Artificial Intelligence
# ...              ...             ...                      ...
# 3570         Headout   United States                   Travel
# 3571            OLIO  United Kingdom                 Wellness
# 3572  Trees for Life  United Kingdom                 Wellness
# 3573     Britishvolt  United Kingdom                 Wellness
# 3574         Greenly          France                 Wellness
#
#       Funding Amount (USD) Funding Stage Funding Date
# 0                 278940.0          Seed       20-Jan
# 1                 292244.0          Seed       20-Jan
# 2                 300000.0          Seed       20-Jan
# 3                 300000.0          Seed       20-Jan
# 4                 529013.0          Seed       20-Jan
# ...                    ...           ...          ...
# 3570            12000000.0      Series B       21-Sep
# 3571            43000000.0      Series B       21-Sep
# 3572             2737468.0  Crowdfunding       21-Sep
# 3573            70000000.0      Series B       21-Sep
# 3574             2953675.0          Seed       21-Sep
#
# [3575 rows x 6 columns]

# %%
# Delete a row at index 1
dataset.drop([1], axis=0).head(5)
# Out:
#      Company                   Website          Region  \
# 0   Internxt     https://internxt.com/           Spain
# 2  api.video         https://api.video          France
# 3    Buck.ai          https://buck.ai/   United States
# 4  Prodsight  https://www.prodsight.ai  United Kingdom
# 5   Harvestr       http://harvestr.io/          France
#
#                   Vertical  Funding Amount (USD) Funding Stage Funding Date
# 0               Blockchain              278940.0          Seed       20-Jan
# 2           Developer APIs              300000.0          Seed       20-Jan
# 3  Artificial Intelligence              300000.0          Seed       20-Jan
# 4  Artificial Intelligence              529013.0          Seed       20-Jan
# 5             B2B Software              650000.0         Angel       20-Jan

# %% [markdown]
# ################################################################################

# %%
# Find unique values
dataset['Funding Stage'].unique()
# Out:
# array(['Seed', 'Angel', 'Series A', 'Series B', 'Series C', 'Series D',
#        'Series E', 'Series F', 'Series G', 'Debt Financing', 'Pre-Seed',
#        'Unknown', 'ICO', 'Initial Coin Offering', 'Unkown',
#        'Private Equity', 'Undisclosed', 'Grant', 'Series H', 'Funding',
#        'Crowdfunding', 'Growth'], dtype=object)
